# %% [markdown]
# <a href="https://colab.research.google.com/github/dhatchanapset-lang/python/blob/main/day2_dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dictionaries={"A":90,"B":80,"C":70,"D":60,"E":50}
print(dictionaries)
# Out:
# {'A': 90, 'B': 80, 'C': 70, 'D': 60, 'E': 50}

# %%
dictionaries={"A":90,"B":80,"C":70,"D":60,"E":50}
print(max(dictionaries.values()))
print(min(dictionaries.values()))
# Out:
# 90
# 50

# %%
dictionaries={"A":90,"B":80,"C":70,"D":60,"E":50}
print
# Out:
# [50, 60, 70, 80, 90]

# %%
dictionaries={"A":90,"B":80,"C":70,"D":60,"E":50}
avg=sum(dictionaries.values())/len(dictionaries)
print(avg)
# Out:
# 70.0

# %%
dictionaries={"A":90,"B":80,"C":70,"D":60,"E":50}
